# %%
import load_pdf
import pdfplumber

file_path = "..\\test files\\2. Medium Pressure Accel Valves-installation.pdf"

table_setting = {
    "vertical_strategy": "lines", 
    "horizontal_strategy": "lines",
    "intersection_tolerance": 5,
    "snap_tolerance": 5,
    "join_tolerance": 4,
    "text_line_dir_render": "ttb"
}

table_setting2 = {
    "vertical_strategy": "lines", 
    "horizontal_strategy": "text",
    "intersection_tolerance": 2,
    "edge_min_length": 10,
    "snap_tolerance": 1,
    "join_tolerance": 1,
    # "min_words_vertical": 5,
    "min_words_horizontal": 5,
}

# %%
pdf = pdfplumber.open(file_path)

p0 = pdf.pages[0]
im = p0.to_image()
# im.debug_tablefinder(table_settings = table_setting)
im.debug_tablefinder(table_settings = table_setting2)
# im.draw_rects(p0.extract_words(use_text_flow=True, x_tolerance=2, extra_attrs=["fontname"]))
# p0.extract_text(use_text_flow=True, x_tolerance=1, layout=True)

# %%
finlist = load_pdf.load_pdf(file_path)
# Out:
# top_headers: ['cA', 'normally closed\nshown)']
#
# semantic rows: ['[xineohP, normally closed\nshown)]: D']
#
# top_headers: ['', '']
#
# semantic rows: ['[Row, ]: N/A']
#
#
# semantic rows: ['[Row, ]: N/A', '[Row, ]: N/A']
#
#
# semantic rows: ['[Row, ]: N/A', '[Row, ]: N/A', '[Row, ]: N/A']
#
#
# semantic rows: ['[Row, ]: N/A', '[Row, ]: N/A', '[Row, ]: N/A', '[Row, ]: N/A']
#
#
# semantic rows: ['[Row, ]: N/A', '[Row, ]: N/A', '[Row, ]: N/A', '[Row, ]: N/A', '[Row, ]: N/A']

# %%
# for i in finlist:
#     print(len(i))
